# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahgloria070713-design/Comsci1Prac/blob/main/Gloria_8_Rosal_Prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter number:"))

if num % 2 == 0:
  display(f"The number {num} is even")
else:
  display(f"The number {num} is odd")
# Out:
# Enter number:2
# 'The number 2 is even'
